# %% [markdown]
# # NASDAQ - AT&T, T-Mobile, Verizon

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
att = pd.read_csv("T.csv")
tm = pd.read_csv("TMUS.csv")
vz = pd.read_csv("VZ.csv")

# %%
att["Date"] = pd.to_datetime(att['Date'])
tm["Date"] = pd.to_datetime(tm['Date'])
vz["Date"] = pd.to_datetime(vz['Date'])

# %%
# Calculate the daily percentage change in stock prices
tm['Pct Change'] = (tm['Close'] - tm['Open']) / tm['Open'] * 100
att['Pct Change'] = (att['Close'] - att['Open']) / att['Open'] * 100
vz['Pct Change'] = (vz['Close'] - vz['Open']) / vz['Open'] * 100

# %%
# calculate the daily trading volume for all
tm['Daily Trading Volume'] = tm['Volume'] / tm['Adj. Close']
att['Daily Trading Volume'] = att['Volume'] / att['Adj. Close']
vz['Daily Trading Volume'] = vz['Volume'] / vz['Adj. Close']
display(tm.head())
display(att.head())
display(vz.head())
# Out:
#         Date   Open   High    Low  Close      Volume  Ex-Dividend  \
# 0 2007-04-19  25.10  27.61  24.50  27.40  31724800.0          0.0
# 1 2007-04-20  27.40  28.80  27.10  28.55   6109400.0          0.0
# 2 2007-04-23  28.60  28.94  28.29  28.75   3752800.0          0.0
# 3 2007-04-24  28.51  29.40  28.51  29.20   3065800.0          0.0
# 4 2007-04-25  29.55  29.75  28.51  28.61   2450600.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  Adj. Volume  \
# 0          1.0  33.684159  37.052575  32.878960   36.770755   15862400.0
# 1          1.0  36.770755  38.649553  36.368156   38.314054    3054700.0
# 2          1.0  38.381154  38.837433  37.965134   38.582453    1876400.0
# 3          1.0  38.260374  39.454752  38.260374   39.186353    1532900.0
# 4          1.0  39.656052  39.924452  38.260374   38.394574    1225300.0
#
#    Pct Change  Daily Trading Volume
# 0    9.163347         862772.591506
# 1    4.197080         159455.850362
# 2    0.524476          97267.013370
# 3    2.420203          78236.421606
# 4   -3.181049          63826.727985
#         Date   Open   High    Low  Close    Volume  Ex-Dividend  Split Ratio  \
# 0 1984-07-19  59.75  59.87  59.38  59.38   77900.0          0.0          1.0
# 1 1984-07-20  59.62  60.00  59.25  59.50  129800.0          0.0          1.0
# 2 1984-07-23  59.25  59.75  58.75  59.50  276100.0          0.0          1.0
# 3 1984-07-24  59.75  60.38  59.62  60.00  129100.0          0.0          1.0
# 4 1984-07-25  60.00  61.37  59.87  60.75  152400.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  Pct Change  \
# 0   1.275248   1.277809  1.267351    1.267351     934800.0   -0.619247
# 1   1.272474   1.280584  1.264577    1.269913    1557600.0   -0.201275
# 2   1.264577   1.275248  1.253905    1.269913    3313200.0    0.421941
# 3   1.275248   1.288694  1.272474    1.280584    1549200.0    0.418410
# 4   1.280584   1.309824  1.277809    1.296591    1828800.0    1.250000
#
#    Daily Trading Volume
# 0          61466.774449
# 1         102211.764547
# 2         217416.550012
# 3         100813.374266
# 4         117538.960041
#         Date   Open   High    Low  Close    Volume  Ex-Dividend  Split Ratio  \
# 0 1983-11-21  70.62  70.75  65.62  70.25  627575.0          0.0          1.0
# 1 1983-11-22  70.25  71.25  69.87  70.00  333338.0          0.0          1.0
# 2 1983-11-23  70.00  70.25  69.25  69.62  143988.0          0.0          1.0
# 3 1983-11-25  69.62  69.75  68.87  68.87  221475.0          0.0          1.0
# 4 1983-11-28  68.50  68.50  66.75  67.00  295975.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  Pct Change  \
# 0   1.649837   1.652874  1.533026    1.641193    5020600.0   -0.523931
# 1   1.641193   1.664556  1.632316    1.635353    2666704.0   -0.355872
# 2   1.635353   1.641193  1.617831    1.626475    1151904.0   -0.542857
# 3   1.626475   1.629512  1.608954    1.608954    1771800.0   -1.077277
# 4   1.600310   1.600310  1.559426    1.565266    2367800.0   -2.189781
#
#    Daily Trading Volume
# 0         382389.441079
# 1         203832.471671
# 2          88527.635728
# 3         137651.583830
# 4         189089.238102

# %% [markdown]
# ## Comparative Analyses

# %% [markdown]
# ### Volume

# %%
plt.plot(att["Date"], att["Volume"])
plt.plot(tm["Date"], tm["Volume"])
plt.plot(vz["Date"], vz["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Price

# %%
plt.plot(att["Date"], att["Close"])
plt.plot(tm["Date"], tm["Close"])
plt.plot(vz["Date"], vz["Close"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Daily Trading Volume

# %%
# filter the dataframes for dates between 2017 and 2018
start_date = '2017-01-01'
end_date = '2018-12-31'

t_mobile = tm[(tm['Date'] >= start_date) & (tm['Date'] <= end_date)]
t = att[(att['Date'] >= start_date) & (att['Date'] <= end_date)]
verizon = vz[(vz['Date'] >= start_date) & (vz['Date'] <= end_date)]

# %%
# make line charts for all three files

plt.plot(t_mobile['Date'], t_mobile['Daily Trading Volume'])
plt.title('T-Mobile Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.xticks(rotation=45)
plt.show()

plt.plot(t['Date'], t['Daily Trading Volume'])
plt.title('AT&T Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.xticks(rotation=45)
plt.show()

plt.plot(verizon['Date'], verizon['Daily Trading Volume'])
plt.title('Verizon Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Average daily trading volume from 2017-2018

# %%
# Calculate the average daily trading volume for each company
t_mobile_avg_vol = tm['Volume'].mean()
att_avg_vol = t['Volume'].mean()
verizon_avg_vol = vz['Volume'].mean()

# Print the results
print("T-Mobile's average daily trading volume for 2017-2018 was", t_mobile_avg_vol)
print("AT&T's average daily trading volume for 2017-2018 was", att_avg_vol)
print("Verizon's average daily trading volume for 2017-2018 was", verizon_avg_vol)
# Out:
# T-Mobile's average daily trading volume for 2017-2018 was 5099418.919753087
# AT&T's average daily trading volume for 2017-2018 was 25438714.100323625
# Verizon's average daily trading volume for 2017-2018 was 7391080.3091938095

# %%
# Create a bar chart of the average trading volume
plt.bar(['T-Mobile', 'AT&T', 'Verizon'], [t_mobile_avg_vol, att_avg_vol, verizon_avg_vol])
plt.title('Average Trading Volume for 2017-2018')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ### Daily Percentage Change in Stock Prices

# %%
# Create line chart for T-Mobile's daily percentage change in stock prices
plt.plot(t_mobile['Date'], t_mobile['Pct Change'])
plt.title('T-Mobile Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# Create line chart for AT&T's daily percentage change in stock prices
plt.plot(t['Date'], t['Pct Change'])
plt.title('AT&T Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# Create line chart for Verizon's daily percentage change in stock prices
plt.plot(verizon['Date'], verizon['Pct Change'])
plt.title('Verizon Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# %% [markdown]
# ## AT&T

# %% [markdown]
# ### Volume

# %%
plt.plot(att["Date"], att["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# Notice the spike around the year 1988.

# %% [markdown]
# ### Price

# %%
plt.plot(att["Date"], att["Close"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### 1988: An Instance of Volume Movement Preceding Price Movement

# %%
att_1988 = att[(att["Date"].dt.year >= 1988) & (att["Date"].dt.year <= 1995)]

# %%
plt.plot(att_1988["Date"], att_1988['Volume'])
plt.title("AT&T Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()

# %%
plt.plot(att_1988["Date"], att_1988['Close'])
plt.title("AT&T Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()

# %% [markdown]
# ### Quarterly

# %% [markdown]
# ## T-Mobile

# %% [markdown]
# ### Volume

# %%
plt.plot(tm["Date"], tm["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Price

# %%
plt.plot(tm["Date"], tm["Close"])
plt.title("AT&T Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()

# %% [markdown]
# ### Another Instance of Volume Movement Preceding Price Movement

# %% [markdown]
# Note that, in the volume plot above, there were spikes in volume in 2009, 2011, 2012, and 2013 and there was a rise in price for the following years in the next plot.

# %% [markdown]
# ### Quarterly

# %% [markdown]
# ## Verizon

# %% [markdown]
# ### Volume

# %%
plt.plot(vz["Date"], vz["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Price

# %%
plt.plot(vz["Date"], vz["Close"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Quarterly
