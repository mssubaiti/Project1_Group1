# %% [markdown]
# # NASDAQ - AT&T, T-Mobile, Verizon

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define the API URL with your API key
api_url = 'https://data.nasdaq.com/api/v3/datasets/WIKI/T.csv'

# Set the API key as a query parameter
params = {'API_KEYS': 'API_KEYS'}

# Make a GET request to the API URL with the API key as a parameter
response = requests.get(api_url, params=params)

# Check that the request was successful (status code 200)
if response.status_code == 200:
    # Write the content to a file
    with open('T.csv', 'wb') as f:
        f.write(response.content)
    # Read the file into a Pandas DataFrame
    att = pd.read_csv('T.csv')
else:
    print('Error: could not retrieve data from API.')

# %%
# Define the API URL with your API key
api_url2 = 'https://data.nasdaq.com/api/v3/datasets/WIKI/TMUS.csv'

# Set the API key as a query parameter
params2 = {'API_KEYS': 'API_KEYS'}

# Make a GET request to the API URL with the API key as a parameter
response2 = requests.get(api_url2, params=params2)

# Check that the request was successful (status code 200)
if response2.status_code == 200:
    # Write the content to a file
    with open('TMUS.csv', 'wb') as f:
        f.write(response2.content)
    # Read the file into a Pandas DataFrame
    tm = pd.read_csv('TMUS.csv')
else:
    print('Error: could not retrieve data from API.')

# %%
# Define the API URL with your API key
api_url3 = 'https://data.nasdaq.com/api/v3/datasets/WIKI/VZ.csv'

# Set the API key as a query parameter
params3 = {'API_KEYS': 'API_KEYS'}

# Make a GET request to the API URL with the API key as a parameter
response3 = requests.get(api_url3, params=params3)

# Check that the request was successful (status code 200)
if response3.status_code == 200:
    # Write the content to a file
    with open('VZ.csv', 'wb') as f:
        f.write(response3.content)
    # Read the file into a Pandas DataFrame
    vz = pd.read_csv('VZ.csv')
else:
    print('Error: could not retrieve data from API.')

# %%
att = pd.read_csv("T.csv")
tm = pd.read_csv("TMUS.csv")
vz = pd.read_csv("VZ.csv")

# %%
att["Date"] = pd.to_datetime(att['Date'])
tm["Date"] = pd.to_datetime(tm['Date'])
vz["Date"] = pd.to_datetime(vz['Date'])

# %%
# Calculate the daily percentage change in stock prices
tm['Pct Change'] = (tm['Close'] - tm['Open']) / tm['Open'] * 100
att['Pct Change'] = (att['Close'] - att['Open']) / att['Open'] * 100
vz['Pct Change'] = (vz['Close'] - vz['Open']) / vz['Open'] * 100

# %%
# calculate the daily trading volume for all
tm['Daily Trading Volume'] = tm['Volume'] / tm['Adj. Close']
att['Daily Trading Volume'] = att['Volume'] / att['Adj. Close']
vz['Daily Trading Volume'] = vz['Volume'] / vz['Adj. Close']
display(tm.head())
display(att.head())
display(vz.head())
# Out:
#         Date   Open    High    Low  Close     Volume  Ex-Dividend  \
# 0 2018-03-27  61.66  62.020  60.08  60.34  2260424.0          0.0
# 1 2018-03-26  60.70  61.630  60.18  61.38  3001089.0          0.0
# 2 2018-03-23  61.42  61.765  59.73  59.74  4818088.0          0.0
# 3 2018-03-22  61.84  62.070  61.21  61.25  4094351.0          0.0
# 4 2018-03-21  62.60  63.210  62.52  62.59  2537296.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  \
# 0          1.0      61.66     62.020     60.08       60.34    2260424.0
# 1          1.0      60.70     61.630     60.18       61.38    3001089.0
# 2          1.0      61.42     61.765     59.73       59.74    4818088.0
# 3          1.0      61.84     62.070     61.21       61.25    4094351.0
# 4          1.0      62.60     63.210     62.52       62.59    2537296.0
#
#    Pct Change  Daily Trading Volume
# 0   -2.140772          37461.451773
# 1    1.120264          48893.597263
# 2   -2.735265          80650.954135
# 3   -0.954075          66846.546939
# 4   -0.015974          40538.360761
#         Date   Open     High    Low  Close      Volume  Ex-Dividend  \
# 0 2018-03-27  34.85  35.2000  34.69  34.90  33198184.0          0.0
# 1 2018-03-26  35.06  35.2866  34.44  34.69  31281785.0          0.0
# 2 2018-03-23  35.37  35.9900  34.55  34.70  34260415.0          0.0
# 3 2018-03-22  35.95  36.0400  35.36  35.37  28063362.0          0.0
# 4 2018-03-21  36.34  36.5000  36.00  36.00  16776049.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  \
# 0          1.0      34.85    35.2000     34.69       34.90   33198184.0
# 1          1.0      35.06    35.2866     34.44       34.69   31281785.0
# 2          1.0      35.37    35.9900     34.55       34.70   34260415.0
# 3          1.0      35.95    36.0400     35.36       35.37   28063362.0
# 4          1.0      36.34    36.5000     36.00       36.00   16776049.0
#
#    Pct Change  Daily Trading Volume
# 0    0.143472         951237.363897
# 1   -1.055334         901752.234073
# 2   -1.894261         987331.844380
# 3   -1.613352         793422.731128
# 4   -0.935608         466001.361111
#         Date   Open     High     Low  Close      Volume  Ex-Dividend  \
# 0 2018-03-27  47.10  47.9024  46.840  47.31  13995096.0          0.0
# 1 2018-03-26  46.78  47.1700  46.585  47.07  15253706.0          0.0
# 2 2018-03-23  47.06  47.4550  46.200  46.29  15829967.0          0.0
# 3 2018-03-22  47.10  47.5199  46.770  46.88  14210836.0          0.0
# 4 2018-03-21  47.69  47.9600  47.270  47.28  11039354.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  \
# 0          1.0      47.10    47.9024    46.840       47.31   13995096.0
# 1          1.0      46.78    47.1700    46.585       47.07   15253706.0
# 2          1.0      47.06    47.4550    46.200       46.29   15829967.0
# 3          1.0      47.10    47.5199    46.770       46.88   14210836.0
# 4          1.0      47.69    47.9600    47.270       47.28   11039354.0
#
#    Pct Change  Daily Trading Volume
# 0    0.445860         295816.867470
# 1    0.619923         324064.287232
# 2   -1.636209         341973.795636
# 3   -0.467091         303132.167235
# 4   -0.859719         233488.874788

# %% [markdown]
# ## Comparative Analyses

# %% [markdown]
# ### Volume

# %%
plt.plot(att["Date"], att["Volume"])
plt.plot(tm["Date"], tm["Volume"])
plt.plot(vz["Date"], vz["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Price

# %%
plt.plot(att["Date"], att["Close"])
plt.plot(tm["Date"], tm["Close"])
plt.plot(vz["Date"], vz["Close"])
plt.title("Stock Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Daily Trading Volume

# %%
# filter the dataframes for dates between 2017 and 2018
start_date = '2017-01-01'
end_date = '2018-12-31'

t_mobile = tm[(tm['Date'] >= start_date) & (tm['Date'] <= end_date)]
t = att[(att['Date'] >= start_date) & (att['Date'] <= end_date)]
verizon = vz[(vz['Date'] >= start_date) & (vz['Date'] <= end_date)]

# %%
# Making line charts for all three files
plt.plot(t['Date'], t['Daily Trading Volume'])
plt.title('AT&T Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.xticks(rotation=45)
plt.show()

plt.plot(t_mobile['Date'], t_mobile['Daily Trading Volume'])
plt.title('T-Mobile Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.xticks(rotation=45)
plt.show()

plt.plot(verizon['Date'], verizon['Daily Trading Volume'])
plt.title('Verizon Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Average daily trading volume from 2017-2018

# %%
# Calculate the average daily trading volume for each company
t_mobile_avg_vol = tm['Volume'].mean()
att_avg_vol = t['Volume'].mean()
verizon_avg_vol = vz['Volume'].mean()

# Print the results
print("T-Mobile's average daily trading volume for 2017-2018 was", t_mobile_avg_vol)
print("AT&T's average daily trading volume for 2017-2018 was", att_avg_vol)
print("Verizon's average daily trading volume for 2017-2018 was", verizon_avg_vol)
# Out:
# T-Mobile's average daily trading volume for 2017-2018 was 5099418.919753087
# AT&T's average daily trading volume for 2017-2018 was 25438714.100323625
# Verizon's average daily trading volume for 2017-2018 was 7391080.3091938095

# %%
# Create a bar chart of the average trading volume
plt.bar(['T-Mobile', 'AT&T', 'Verizon'], [t_mobile_avg_vol, att_avg_vol, verizon_avg_vol])
plt.title('Average Trading Volume for 2017-2018')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ### Daily Percentage Change in Stock Prices

# %%
# Create line chart for T-Mobile's daily percentage change in stock prices
plt.plot(t_mobile['Date'], t_mobile['Pct Change'])
plt.title('T-Mobile Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# Create line chart for AT&T's daily percentage change in stock prices
plt.plot(t['Date'], t['Pct Change'])
plt.title('AT&T Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# Create line chart for Verizon's daily percentage change in stock prices
plt.plot(verizon['Date'], verizon['Pct Change'])
plt.title('Verizon Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# %% [markdown]
# ### Average High Per Year

# %%
# Group the data by year and calculate the average value for each year
att_yearly = att.groupby(att['Date'].dt.year).mean()

# Create a line plot of the yearly trend
plt.plot(att_yearly.index, att_yearly['Close'])
plt.xlabel('Year')
plt.ylabel('High')
plt.title('Average High Per Year for AT&T')
plt.show()

# Group the data by year and calculate the average value for each year
tm_yearly = tm.groupby(tm['Date'].dt.year).mean()
# Create a line plot of the yearly trend
plt.plot(tm_yearly.index, tm_yearly['Close'])
plt.xlabel('Year')
plt.ylabel('High')
plt.title('Average High Per Year for T-Mobile')
plt.show()

# Group the data by year and calculate the average value for each year
vz_yearly = vz.groupby(att['Date'].dt.year).mean()
# Create a line plot of the yearly trend
plt.plot(vz_yearly.index, vz_yearly['Close'])
plt.xlabel('Year')
plt.ylabel('High')
plt.title('Average High Per Year for Verizon')
plt.show()

# %% [markdown]
# ### Quarterly Analysis

# %%
# Set the date column as the index
att.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
att_quarterly = att.resample('Q').mean()

# Select the data for the recent 5 years
att_quarterly = att_quarterly.loc['2016-01-01':'2021-12-31']

# Reset the index
att_quarterly = att_quarterly.reset_index()

# Display the first few rows of the DataFrame
display(att_quarterly.head())
# Out:
#         Date       Open       High        Low      Close        Volume  \
# 0 2016-03-31  36.571967  36.874825  36.340759  36.670820  2.888697e+07
# 1 2016-06-30  39.334609  39.578755  39.126641  39.401250  2.125395e+07
# 2 2016-09-30  41.862500  42.085469  41.563922  41.847031  1.991083e+07
# 3 2016-12-31  38.957460  39.328113  38.774762  39.068254  2.466348e+07
# 4 2017-03-31  41.644839  41.864500  41.408334  41.665968  1.956849e+07
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0     0.007869          1.0  33.574112  33.852135  33.361831   33.664793
# 1     0.007500          1.0  36.553584  36.780469  36.360287   36.615463
# 2     0.007500          1.0  39.344408  39.553955  39.063783   39.329880
# 3     0.007619          1.0  37.061274  37.413943  36.887605   37.166840
# 4     0.007903          1.0  40.080370  40.291823  39.852748   40.100724
#
#     Adj. Volume  Pct Change  Daily Trading Volume
# 0  2.888697e+07    0.276495         866733.117699
# 1  2.125395e+07    0.165680         578706.358891
# 2  1.991083e+07   -0.033783         507676.753754
# 3  2.466348e+07    0.310955         672907.360108
# 4  1.956849e+07    0.054290         488252.979263

# %%
# Set the date column as the index
tm.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
tm_quarterly = tm.resample('Q').mean()

# Select the data for the recent 5 years
tm_quarterly = tm_quarterly.loc['2016-01-01':'2021-12-31']

# Reset the index
tm_quarterly = tm_quarterly.reset_index()

# Display the first few rows of the DataFrame
display(tm_quarterly.head())
# Out:
#         Date       Open       High        Low      Close        Volume  \
# 0 2016-03-31  37.805410  38.312049  37.098115  37.749836  4.527204e+06
# 1 2016-06-30  40.862812  41.380483  40.508423  41.008984  4.305100e+06
# 2 2016-09-30  45.903906  46.322227  45.466628  45.909531  2.741945e+06
# 3 2016-12-31  52.170317  52.808997  51.698816  52.324365  3.910348e+06
# 4 2017-03-31  61.320484  62.059661  60.704284  61.472823  4.946769e+06
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0          0.0          1.0  37.805410  38.312049  37.098115   37.749836
# 1          0.0          1.0  40.862812  41.380483  40.508423   41.008984
# 2          0.0          1.0  45.903906  46.322227  45.466628   45.909531
# 3          0.0          1.0  52.170317  52.808997  51.698816   52.324365
# 4          0.0          1.0  61.320484  62.059661  60.704284   61.472823
#
#     Adj. Volume  Pct Change  Daily Trading Volume
# 0  4.527204e+06   -0.126828         120539.421904
# 1  4.305100e+06    0.363566         105546.349656
# 2  2.741945e+06    0.017942          59807.985721
# 3  3.910348e+06    0.317028          75368.074400
# 4  4.946769e+06    0.259725          80421.925103

# %%
# Set the date column as the index
vz.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
vz_quarterly = vz.resample('Q').mean()

# Select the data for the recent 5 years
vz_quarterly = vz_quarterly.loc['2016-01-01':'2021-12-31']

# Reset the index
vz_quarterly = vz_quarterly.reset_index()

# Display the first few rows of the DataFrame
display(vz_quarterly.head())
# Out:
#         Date       Open       High        Low      Close        Volume  \
# 0 2016-03-31  49.858361  50.294567  49.490861  50.014262  1.793030e+07
# 1 2016-06-30  51.808375  52.145919  51.461944  51.869063  1.365343e+07
# 2 2016-09-30  53.730391  53.997711  53.334333  53.670313  1.257006e+07
# 3 2016-12-31  49.963016  50.304635  49.628525  49.978095  1.411764e+07
# 4 2017-03-31  50.183790  50.448466  49.867661  50.170323  1.568193e+07
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0     0.009262          1.0  47.194635  47.607578  46.846807   47.342166
# 1     0.008828          1.0  49.551277  49.874081  49.219907   49.609226
# 2     0.008828          1.0  51.915264  52.173476  51.532500   51.857108
# 3     0.009167          1.0  48.827323  49.161219  48.500492   48.842148
# 4     0.009306          1.0  49.565040  49.826426  49.252792   49.551654
#
#     Adj. Volume  Pct Change  Daily Trading Volume
# 0  1.793030e+07    0.316562         383721.818594
# 1  1.365343e+07    0.115801         274388.875425
# 2  1.257006e+07   -0.109923         242473.503741
# 3  1.411764e+07    0.029942         291384.122323
# 4  1.568193e+07   -0.023290         317234.742500

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the line chart
plt.plot(att_quarterly['Date'], att_quarterly['Close'], label="AT&T")
# Set the title and axis labels
plt.title('AT&T Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Create the line chart
plt.plot(tm_quarterly['Date'], tm_quarterly['High'], label="T-Mobile")
# Set the title and axis labels
plt.title('tmus Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Create the line chart
plt.plot(vz_quarterly['Date'], vz_quarterly['High'], label="Verizon")
# Set the title and axis labels
plt.title('vz Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')
plt.legend(loc="best")

# Show the plot
plt.show()

# %% [markdown]
# ## AT&T

# %% [markdown]
# ### Volume

# %%
plt.plot(att["Date"], att["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14140\773322969.py in <module>
# ----> 1 plt.plot(att["Date"], att["Volume"])
#       2 plt.title("AT&T Volume Over Time")
#       3 plt.xlabel("Date")
#       4 plt.ylabel("Volume")
#       5 plt.show()
#
# c:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# c:\Users\aloun\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %% [markdown]
# Notice the spike around the year 1988.

# %% [markdown]
# ### Price

# %%
plt.plot(att["Date"], att["Close"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### 1988: An Instance of Volume Movement Preceding Price Movement

# %%
att_1988 = att[(att["Date"].dt.year >= 1988) & (att["Date"].dt.year <= 1995)]

# %%
plt.plot(att_1988["Date"], att_1988['Volume'])
plt.title("AT&T Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()

# %%
plt.plot(att_1988["Date"], att_1988['Close'])
plt.title("AT&T Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()

# %% [markdown]
# ### Quarterly Analysis

# %%
# Set the date column as the index
att.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
att_quarterly = att.resample('Q').mean()

# Select the data for the recent 5 years
att_quarterly = att_quarterly.loc['2016-01-01':'2021-12-31']

# Reset the index
att_quarterly = att_quarterly.reset_index()

# Display the first few rows of the DataFrame
display(att_quarterly.head())
# Out:
#         Date       Open       High        Low      Close        Volume  \
# 0 2016-03-31  36.571967  36.874825  36.340759  36.670820  2.888697e+07
# 1 2016-06-30  39.334609  39.578755  39.126641  39.401250  2.125395e+07
# 2 2016-09-30  41.862500  42.085469  41.563922  41.847031  1.991083e+07
# 3 2016-12-31  38.957460  39.328113  38.774762  39.068254  2.466348e+07
# 4 2017-03-31  41.644839  41.864500  41.408334  41.665968  1.956849e+07
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0     0.007869          1.0  33.574112  33.852135  33.361831   33.664793
# 1     0.007500          1.0  36.553584  36.780469  36.360287   36.615463
# 2     0.007500          1.0  39.344408  39.553955  39.063783   39.329880
# 3     0.007619          1.0  37.061274  37.413943  36.887605   37.166840
# 4     0.007903          1.0  40.080370  40.291823  39.852748   40.100724
#
#     Adj. Volume  Pct Change  Daily Trading Volume
# 0  2.888697e+07    0.276495         866733.117699
# 1  2.125395e+07    0.165680         578706.358891
# 2  1.991083e+07   -0.033783         507676.753754
# 3  2.466348e+07    0.310955         672907.360108
# 4  1.956849e+07    0.054290         488252.979263

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the line chart
plt.plot(att_quarterly['Date'], att_quarterly['Close'])

# Set the title and axis labels
plt.title('AT&T Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Show the plot
plt.show()

# %% [markdown]
# ## T-Mobile

# %% [markdown]
# ### Volume

# %%
plt.plot(tm["Date"], tm["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Price

# %%
plt.plot(tm["Date"], tm["Close"])
plt.title("AT&T Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.show()

# %% [markdown]
# ### Another Instance of Volume Movement Preceding Price Movement

# %% [markdown]
# Note that, in the volume plot above, there were spikes in volume in 2009, 2011, 2012, and 2013 and that there was a rise in price for the following years in the next plot.

# %% [markdown]
# ### Quarterly Analysis

# %%
# Set the date column as the index
tm.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
tm_quarterly = tm.resample('Q').mean()

# Select the data for the recent 5 years
tm_quarterly = tm_quarterly.loc['2016-01-01':'2021-12-31']

# Reset the index
tm_quarterly = tm_quarterly.reset_index()

# Display the first few rows of the DataFrame
display(tm_quarterly.head())
# Out:
#         Date       Open       High        Low      Close        Volume  \
# 0 2016-03-31  37.805410  38.312049  37.098115  37.749836  4.527204e+06
# 1 2016-06-30  40.862812  41.380483  40.508423  41.008984  4.305100e+06
# 2 2016-09-30  45.903906  46.322227  45.466628  45.909531  2.741945e+06
# 3 2016-12-31  52.170317  52.808997  51.698816  52.324365  3.910348e+06
# 4 2017-03-31  61.320484  62.059661  60.704284  61.472823  4.946769e+06
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0          0.0          1.0  37.805410  38.312049  37.098115   37.749836
# 1          0.0          1.0  40.862812  41.380483  40.508423   41.008984
# 2          0.0          1.0  45.903906  46.322227  45.466628   45.909531
# 3          0.0          1.0  52.170317  52.808997  51.698816   52.324365
# 4          0.0          1.0  61.320484  62.059661  60.704284   61.472823
#
#     Adj. Volume  Pct Change  Daily Trading Volume
# 0  4.527204e+06   -0.126828         120539.421904
# 1  4.305100e+06    0.363566         105546.349656
# 2  2.741945e+06    0.017942          59807.985721
# 3  3.910348e+06    0.317028          75368.074400
# 4  4.946769e+06    0.259725          80421.925103

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the line chart
plt.plot(tm_quarterly['Date'], tm_quarterly['High'])

# Set the title and axis labels
plt.title('T-Mobile Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Show the plot
plt.show()

# %% [markdown]
# ## Verizon

# %% [markdown]
# ### Volume

# %%
plt.plot(vz["Date"], vz["Volume"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Price

# %%
plt.plot(vz["Date"], vz["Close"])
plt.title("AT&T Volume Over Time")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %% [markdown]
# ### Average High Per Year

# %% [markdown]
# ### Quarterly Analysis

# %%
# Convert the date column to datetime format
vz['Date'] = pd.to_datetime(vz['Date'])

# Set the date column as the index
vz.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
vz_quarterly = vz.resample('Q').mean()

# Select the data for the recent 5 years
vz_quarterly = vz_quarterly.loc['2016-01-01':'2021-12-31']

# Reset the index
vz_quarterly = vz_quarterly.reset_index()

# Display the first few rows of the DataFrame
display(vz_quarterly.head())
# Out:
#         Date       Open       High        Low      Close        Volume  \
# 0 2016-03-31  49.858361  50.294567  49.490861  50.014262  1.793030e+07
# 1 2016-06-30  51.808375  52.145919  51.461944  51.869063  1.365343e+07
# 2 2016-09-30  53.730391  53.997711  53.334333  53.670313  1.257006e+07
# 3 2016-12-31  49.963016  50.304635  49.628525  49.978095  1.411764e+07
# 4 2017-03-31  50.183790  50.448466  49.867661  50.170323  1.568193e+07
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0     0.009262          1.0  47.194635  47.607578  46.846807   47.342166
# 1     0.008828          1.0  49.551277  49.874081  49.219907   49.609226
# 2     0.008828          1.0  51.915264  52.173476  51.532500   51.857108
# 3     0.009167          1.0  48.827323  49.161219  48.500492   48.842148
# 4     0.009306          1.0  49.565040  49.826426  49.252792   49.551654
#
#     Adj. Volume  Pct Change  Daily Trading Volume
# 0  1.793030e+07    0.316562         383721.818594
# 1  1.365343e+07    0.115801         274388.875425
# 2  1.257006e+07   -0.109923         242473.503741
# 3  1.411764e+07    0.029942         291384.122323
# 4  1.568193e+07   -0.023290         317234.742500

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the line chart
plt.plot(vz_quarterly['Date'], vz_quarterly['High'])

# Set the title and axis labels
plt.title('vz Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Show the plot
plt.show()
