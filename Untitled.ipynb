# %%
# Dependencies and Setup
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the API key
from API_KEYS import API_KEYS

# %%
# Define the API URL with your API key
api_url = 'https://data.nasdaq.com/api/v3/datasets/WIKI/T.csv'

# Set the API key as a query parameter
params = {'API_KEYS': 'API_KEYS'}

# Make a GET request to the API URL with the API key as a parameter
response = requests.get(api_url, params=params)

# Check that the request was successful (status code 200)
if response.status_code == 200:
    # Write the content to a file
    with open('T.csv', 'wb') as f:
        f.write(response.content)
    # Read the file into a Pandas DataFrame
    df = pd.read_csv('T.csv')
    # Display the first few rows of the DataFrame
    display(df.head())
else:
    print('Error: could not retrieve data from API.')
# Out:
#          Date   Open     High    Low  Close      Volume  Ex-Dividend  \
# 0  2018-03-27  34.85  35.2000  34.69  34.90  33198184.0          0.0
# 1  2018-03-26  35.06  35.2866  34.44  34.69  31281785.0          0.0
# 2  2018-03-23  35.37  35.9900  34.55  34.70  34260415.0          0.0
# 3  2018-03-22  35.95  36.0400  35.36  35.37  28063362.0          0.0
# 4  2018-03-21  36.34  36.5000  36.00  36.00  16776049.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0          1.0      34.85    35.2000     34.69       34.90   33198184.0
# 1          1.0      35.06    35.2866     34.44       34.69   31281785.0
# 2          1.0      35.37    35.9900     34.55       34.70   34260415.0
# 3          1.0      35.95    36.0400     35.36       35.37   28063362.0
# 4          1.0      36.34    36.5000     36.00       36.00   16776049.0

# %%
# Export the Data into a csv
df.to_csv("output_data/T.csv")

# %%
# Read the CSV file into a pandas DataFrame
df = pd.read_csv('output_data/T.csv')
df2 = pd.read_csv('output_data/TMUS.csv')
df3 = pd.read_csv('output_data/VZ.csv')

# Convert the "Date" column to a pandas datetime object
df['Date'] = pd.to_datetime(df['Date'])
df2['Date'] = pd.to_datetime(df2['Date'])
df3['Date'] = pd.to_datetime(df3['Date'])

# %%
# Group the data by year and calculate the average value for each year
df_yearly = df.groupby(df['Date'].dt.year).mean()

# Create a line plot of the yearly trend
plt.plot(df_yearly.index, df_yearly['Close'])
plt.xlabel('Year')
plt.ylabel('High')
plt.title('Stock')
plt.show()
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_51740\3477022906.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_yearly = df.groupby(df['Date'].dt.year).mean()

# %%
   
# Define the API URL with your API key
api_url2 = 'https://data.nasdaq.com/api/v3/datasets/WIKI/TMUS.csv'

# Set the API key as a query parameter
params2 = {'API_KEYS': 'API_KEYS'}

# Make a GET request to the API URL with the API key as a parameter
response2 = requests.get(api_url2, params=params2)

# Check that the request was successful (status code 200)
if response2.status_code == 200:
    # Write the content to a file
    with open('TMUS.csv', 'wb') as f:
        f.write(response2.content)
    # Read the file into a Pandas DataFrame
    df2 = pd.read_csv('TMUS.csv')
    # Display the first few rows of the DataFrame
    display(df2.head())
else:
    print('Error: could not retrieve data from API.')
# Out:
#          Date   Open    High    Low  Close     Volume  Ex-Dividend  \
# 0  2018-03-27  61.66  62.020  60.08  60.34  2260424.0          0.0
# 1  2018-03-26  60.70  61.630  60.18  61.38  3001089.0          0.0
# 2  2018-03-23  61.42  61.765  59.73  59.74  4818088.0          0.0
# 3  2018-03-22  61.84  62.070  61.21  61.25  4094351.0          0.0
# 4  2018-03-21  62.60  63.210  62.52  62.59  2537296.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0          1.0      61.66     62.020     60.08       60.34    2260424.0
# 1          1.0      60.70     61.630     60.18       61.38    3001089.0
# 2          1.0      61.42     61.765     59.73       59.74    4818088.0
# 3          1.0      61.84     62.070     61.21       61.25    4094351.0
# 4          1.0      62.60     63.210     62.52       62.59    2537296.0

# %%
# Group the data by year and calculate the average value for each year
df2['Date'] = pd.to_datetime(df2['Date'])
df_yearly2 = df2.groupby(df2['Date'].dt.year).mean()


# Create a line plot of the yearly trend
plt.plot(df_yearly2.index, df_yearly2['Close'])
plt.xlabel('Year')
plt.ylabel('High')
plt.title('Stock')
plt.show()
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_51740\1443862209.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_yearly2 = df2.groupby(df2['Date'].dt.year).mean()

# %%
# Define the API URL with your API key
api_url3 = 'https://data.nasdaq.com/api/v3/datasets/WIKI/VZ.csv'

# Set the API key as a query parameter
params3 = {'API_KEYS': 'API_KEYS'}

# Make a GET request to the API URL with the API key as a parameter
response3 = requests.get(api_url3, params=params3)

# Check that the request was successful (status code 200)
if response3.status_code == 200:
    # Write the content to a file
    with open('VZ.csv', 'wb') as f:
        f.write(response3.content)
    # Read the file into a Pandas DataFrame
    df3 = pd.read_csv('VZ.csv')
    # Display the first few rows of the DataFrame
    display(df3.head())
else:
    print('Error: could not retrieve data from API.')
# Out:
#          Date   Open     High     Low  Close      Volume  Ex-Dividend  \
# 0  2018-03-27  47.10  47.9024  46.840  47.31  13995096.0          0.0
# 1  2018-03-26  46.78  47.1700  46.585  47.07  15253706.0          0.0
# 2  2018-03-23  47.06  47.4550  46.200  46.29  15829967.0          0.0
# 3  2018-03-22  47.10  47.5199  46.770  46.88  14210836.0          0.0
# 4  2018-03-21  47.69  47.9600  47.270  47.28  11039354.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# 0          1.0      47.10    47.9024    46.840       47.31   13995096.0
# 1          1.0      46.78    47.1700    46.585       47.07   15253706.0
# 2          1.0      47.06    47.4550    46.200       46.29   15829967.0
# 3          1.0      47.10    47.5199    46.770       46.88   14210836.0
# 4          1.0      47.69    47.9600    47.270       47.28   11039354.0

# %%
# Group the data by year and calculate the average value for each year
df_yearly3 = df3.groupby(df['Date'].dt.year).mean()

# Create a line plot of the yearly trend
plt.plot(df_yearly3.index, df_yearly3['Close'])
plt.xlabel('Year')
plt.ylabel('High')
plt.title('Stock')
#plt.show()
# Out:
# C:\Users\joshu\AppData\Local\Temp\ipykernel_51740\689863285.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_yearly3 = df3.groupby(df['Date'].dt.year).mean()
# Text(0.5, 1.0, 'Stock')

# %%
#quarters

# Convert the date column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Set the date column as the index
df.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
df_quarterly = df.resample('Q').mean()

# Select the data for the recent 5 years
df_quarterly = df_quarterly.loc['2016-01-01':'2021-12-31']

# Reset the index
df_quarterly = df_quarterly.reset_index()

# Display the first few rows of the DataFrame
display(df_quarterly.head())
# Out:
#         Date  Unnamed: 0       Open       High        Low      Close  \
# 0 2016-03-31       530.0  36.571967  36.874825  36.340759  36.670820
# 1 2016-06-30       467.5  39.334609  39.578755  39.126641  39.401250
# 2 2016-09-30       403.5  41.862500  42.085469  41.563922  41.847031
# 3 2016-12-31       340.0  38.957460  39.328113  38.774762  39.068254
# 4 2017-03-31       277.5  41.644839  41.864500  41.408334  41.665968
#
#          Volume  Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  \
# 0  2.888697e+07     0.007869          1.0  33.574112  33.852135  33.361831
# 1  2.125395e+07     0.007500          1.0  36.553584  36.780469  36.360287
# 2  1.991083e+07     0.007500          1.0  39.344408  39.553955  39.063783
# 3  2.466348e+07     0.007619          1.0  37.061274  37.413943  36.887605
# 4  1.956849e+07     0.007903          1.0  40.080370  40.291823  39.852748
#
#    Adj. Close   Adj. Volume
# 0   33.664793  2.888697e+07
# 1   36.615463  2.125395e+07
# 2   39.329880  1.991083e+07
# 3   37.166840  2.466348e+07
# 4   40.100724  1.956849e+07

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the line chart
plt.plot(df_quarterly['Date'], df_quarterly['Close'])

# Set the title and axis labels
plt.title('AT&T Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Show the plot
plt.show()

# %%
df2 = df2.reset_index()

# %%
# Convert the date column to datetime format
df2['Date'] = pd.to_datetime(df2['Date'])

# Set the date column as the index
df2.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
df_quarterly2 = df2.resample('Q').mean()

# Select the data for the recent 5 years
df_quarterly2 = df_quarterly2.loc['2016-01-01':'2021-12-31']

# Reset the index
df_quarterly2 = df_quarterly2.reset_index()

# Display the first few rows of the DataFrame
display(df_quarterly2.head())
# Out:
#         Date  index       Open       High        Low      Close        Volume  \
# 0 2016-03-31  530.0  37.805410  38.312049  37.098115  37.749836  4.527204e+06
# 1 2016-06-30  467.5  40.862812  41.380483  40.508423  41.008984  4.305100e+06
# 2 2016-09-30  403.5  45.903906  46.322227  45.466628  45.909531  2.741945e+06
# 3 2016-12-31  340.0  52.170317  52.808997  51.698816  52.324365  3.910348e+06
# 4 2017-03-31  277.5  61.320484  62.059661  60.704284  61.472823  4.946769e+06
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0          0.0          1.0  37.805410  38.312049  37.098115   37.749836
# 1          0.0          1.0  40.862812  41.380483  40.508423   41.008984
# 2          0.0          1.0  45.903906  46.322227  45.466628   45.909531
# 3          0.0          1.0  52.170317  52.808997  51.698816   52.324365
# 4          0.0          1.0  61.320484  62.059661  60.704284   61.472823
#
#     Adj. Volume
# 0  4.527204e+06
# 1  4.305100e+06
# 2  2.741945e+06
# 3  3.910348e+06
# 4  4.946769e+06

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the line chart
plt.plot(df_quarterly2['Date'], df_quarterly2['High'])

# Set the title and axis labels
plt.title('tmus Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Show the plot
plt.show()

# %%
df3 = df3.reset_index()

# %%
# Convert the date column to datetime format
df3['Date'] = pd.to_datetime(df3['Date'])

# Set the date column as the index
df3.set_index('Date', inplace=True)

# Resample the data quarterly and calculate the mean price for each quarter
df_quarterly3 = df3.resample('Q').mean()

# Select the data for the recent 5 years
df_quarterly3 = df_quarterly3.loc['2016-01-01':'2021-12-31']

# Reset the index
df_quarterly3 = df_quarterly3.reset_index()

# Display the first few rows of the DataFrame
display(df_quarterly3.head())
# Out:
#         Date  index       Open       High        Low      Close        Volume  \
# 0 2016-03-31  530.0  49.858361  50.294567  49.490861  50.014262  1.793030e+07
# 1 2016-06-30  467.5  51.808375  52.145919  51.461944  51.869062  1.365343e+07
# 2 2016-09-30  403.5  53.730391  53.997711  53.334333  53.670313  1.257006e+07
# 3 2016-12-31  340.0  49.963016  50.304635  49.628525  49.978095  1.411764e+07
# 4 2017-03-31  277.5  50.183790  50.448466  49.867661  50.170323  1.568193e+07
#
#    Ex-Dividend  Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# 0     0.009262          1.0  47.194635  47.607578  46.846807   47.342166
# 1     0.008828          1.0  49.551277  49.874081  49.219907   49.609226
# 2     0.008828          1.0  51.915264  52.173476  51.532500   51.857108
# 3     0.009167          1.0  48.827323  49.161219  48.500492   48.842148
# 4     0.009306          1.0  49.565040  49.826426  49.252792   49.551654
#
#     Adj. Volume
# 0  1.793030e+07
# 1  1.365343e+07
# 2  1.257006e+07
# 3  1.411764e+07
# 4  1.568193e+07

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Create the line chart
plt.plot(df_quarterly3['Date'], df_quarterly3['High'])

# Set the title and axis labels
plt.title('vz Stock Price (Quarterly, 2016-2018)')
plt.xlabel('Date')
plt.ylabel('Stock Price ($)')

# Show the plot
plt.show()
