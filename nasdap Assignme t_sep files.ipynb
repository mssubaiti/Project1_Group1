# %%
#Dependecies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
#import nasdaqdatalink as ndl
from scipy.stats import linregress

# %% [raw]
# Presentation Requirements
# You will prepare a formal 10-minute presentation that covers the following topics:
# Questions that you found interesting and what motivated you to answer them
# Where and how you found the data you used to answer these questions
# The data exploration and cleanup process (accompanied by your Jupyter notebook) The analysis process (accompanied by your Jupyter notebook)
# Your conclusions, including a numerical summary and visualizations of the summary The implications of your findings: what do your findings mean?

# %%
# read in the dataframes
t_mobile = pd.read_csv('resources/WIKI-TMUS copy.csv', delimiter=',')
att = pd.read_csv('resources/WIKI-T copy.csv', delimiter=',')
verizon = pd.read_csv('resources/WIKI-VZ copy.csv', delimiter=',')

# %% [markdown]
# # Calculate the daily percentage change in stock prices and use this information to compare the performance of the three companies over a given period.
#     a. Line chart to visualize the daily trading volume for each company over time.
#     b. Over 2017-2018

# %%
# Convert the date column to datetime object
t_mobile['Date'] = pd.to_datetime(t_mobile['Date'])
att['Date'] = pd.to_datetime(att['Date'])
verizon['Date'] = pd.to_datetime(verizon['Date'])

# filter the dataframes for dates between 2017 and 2018
start_date = '2017-01-01'
end_date = '2018-12-31'

t_mobile = t_mobile[(t_mobile['Date'] >= start_date) & (t_mobile['Date'] <= end_date)]
att = att[(att['Date'] >= start_date) & (att['Date'] <= end_date)]
verizon = verizon[(verizon['Date'] >= start_date) & (verizon['Date'] <= end_date)]

# calculate the daily trading volume for all
t_mobile['Daily Trading Volume'] = t_mobile['Volume'] / t_mobile['Adj. Close']
att['Daily Trading Volume'] = att['Volume'] / att['Adj. Close']
verizon['Daily Trading Volume'] = verizon['Volume'] / verizon['Adj. Close']

# %%
# make line charts for all three files

plt.plot(t_mobile['Date'], t_mobile['Daily Trading Volume'])
plt.title('T-Mobile Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.show()

plt.plot(att['Date'], att['Daily Trading Volume'])
plt.title('AT&T Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.show()

plt.plot(verizon['Date'], verizon['Daily Trading Volume'])
plt.title('Verizon Daily Trading Volume (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Daily Trading Volume')
plt.show()

# %%
# same graph 2017 - 2018
# Limit data to 2017-2018


# Create plot
plt.plot(t_mobile['Date'], t_mobile_daily_volume, label='T-Mobile')
plt.plot(att['Date'], att_daily_volume, label='AT&T')
plt.plot(verizon['Date'], verizon_daily_volume, label='Verizon')

# Set plot title and axis labels
plt.title('Daily Trading Volume of Telecom Companies (2017-2018)')
plt.xlabel('Date')
plt.ylabel('Volume')

# Add legend and show plot
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13520\3320871307.py in <module>
#       4
#       5 # Create plot
# ----> 6 plt.plot(t_mobile['Date'], t_mobile_daily_volume, label='T-Mobile')
#       7 plt.plot(att['Date'], att_daily_volume, label='AT&T')
#       8 plt.plot(verizon['Date'], verizon_daily_volume, label='Verizon')
#
# NameError: name 't_mobile_daily_volume' is not defined

# %% [raw]
# t_mobile = t_mobile[(t_mobile['Date'] >= '2017-01-01') & (t_mobile['Date'] <= '2018-12-31')]
# att = att[(att['Date'] >= '2017-01-01') & (att['Date'] <= '2018-12-31')]
# verizon = verizon[(verizon['Date'] >= '2017-01-01') & (verizon['Date'] <= '2018-12-31')]
#
# # Calculate daily trading volume for each company
# t_mobile_daily_volume = t_mobile['Volume']
# att_daily_volume = att['Volume']
# verizon_daily_volume = verizon['Volume']

# %% [markdown]
# # Average daily trading volume from 2017-2018

# %%
# Calculate the average daily trading volume for each company
t_mobile_avg_vol = t_mobile['Volume'].mean()
att_avg_vol = att['Volume'].mean()
verizon_avg_vol = verizon['Volume'].mean()

# Print the results
print("T-Mobile's average daily trading volume for 2017-2018 was", t_mobile_avg_vol)
print("AT&T's average daily trading volume for 2017-2018 was", att_avg_vol)
print("Verizon's average daily trading volume for 2017-2018 was", verizon_avg_vol)
# Out:
# T-Mobile's average daily trading volume for 2017-2018 was 4114494.6860841424
# AT&T's average daily trading volume for 2017-2018 was 25438714.100323625
# Verizon's average daily trading volume for 2017-2018 was 15796332.313915858

# %%
# Create a bar chart of the average trading volume
plt.bar(['T-Mobile', 'AT&T', 'Verizon'], [t_mobile_avg_vol, att_avg_vol, verizon_avg_vol])
plt.title('Average Trading Volume for 2017-2018')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# # using the open and close prices analyze the daily performance of each stock by calculating the daily percentage change in stock prices

# %%
# Calculate the daily percentage change in stock prices
t_mobile['Pct Change'] = (t_mobile['Close'] - t_mobile['Open']) / t_mobile['Open'] * 100
att['Pct Change'] = (att['Close'] - att['Open']) / att['Open'] * 100
verizon['Pct Change'] = (verizon['Close'] - verizon['Open']) / verizon['Open'] * 100

# %%
t_mobile.head()
# Out:
#         Date   Open    High    Low  Close     Volume  Ex-Dividend  \
# 0 2018-03-27  61.66  62.020  60.08  60.34  2260424.0          0.0
# 1 2018-03-26  60.70  61.630  60.18  61.38  3001089.0          0.0
# 2 2018-03-23  61.42  61.765  59.73  59.74  4818088.0          0.0
# 3 2018-03-22  61.84  62.070  61.21  61.25  4094351.0          0.0
# 4 2018-03-21  62.60  63.210  62.52  62.59  2537296.0          0.0
#
#    Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume  \
# 0          1.0      61.66     62.020     60.08       60.34    2260424.0
# 1          1.0      60.70     61.630     60.18       61.38    3001089.0
# 2          1.0      61.42     61.765     59.73       59.74    4818088.0
# 3          1.0      61.84     62.070     61.21       61.25    4094351.0
# 4          1.0      62.60     63.210     62.52       62.59    2537296.0
#
#    Daily Trading Volume  Pct Change
# 0          37461.451773   -2.140772
# 1          48893.597263    1.120264
# ...

# %%
# Create line chart for T-Mobile's daily percentage change in stock prices
plt.plot(t_mobile['Date'], t_mobile['Pct Change'])
plt.title('T-Mobile Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# Create line chart for AT&T's daily percentage change in stock prices
plt.plot(att['Date'], att['Pct Change'])
plt.title('AT&T Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()

# Create line chart for Verizon's daily percentage change in stock prices
plt.plot(verizon['Date'], verizon['Pct Change'])
plt.title('Verizon Daily Percentage Change in Stock Prices')
plt.xlabel('Date')
plt.ylabel('Percentage Change')
plt.show()
